# %% [markdown]
# # Combining & organizing data

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import pandas as pd
import numpy as np
import fnmatch

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_03

# %% [markdown]
# ## Importing the prepared rental apartments data

# %%
# Read data to pandas data frame
df_orig = pd.read_csv('apartments_data_prepared.csv', 
                      sep=',', 
                      encoding='utf-8')

# Copy of data with selected colums
columns = [ 'web-scraper-order', 
            'address_raw',
            'rooms', 
            'area', 
            'luxurious',
            'price',
            'price_per_m2']
df = df_orig[columns]

# Get number of rows and columns
print(df.shape)

# Show first records
df.head(5)
# Out:
# (865, 7)
#   web-scraper-order                          address_raw  rooms  area  \
# 0      1693998201-1    Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0  49.0
# 1      1693998201-2   Zürcherstrasse 1, 8173 Neerach, ZH    3.5  65.0
# 2      1693998201-4  Cramerstrasse 8-12, 8004 Zürich, ZH    2.0  54.0
# 3      1693998201-5    Rotachstrasse 33, 8003 Zürich, ZH    2.0  49.0
# 4     1693998201-16      Wolframplatz 1, 8045 Zürich, ZH    2.0  32.0
#
#    luxurious   price  price_per_m2
# 0          0  1441.0         29.41
# 1          0  1850.0         28.46
# 2          0  4853.0         89.87
# 3          0  4335.0         88.47
# 4          0  3515.0        109.84

# %% [markdown]
# ## Combining data from different sources

# %% [markdown]
# ### Reading rental apartment data with geocoded addresses

# %%
# Meaning of variables
# lat: geographical latitude
# lon: geographical longitude
# bfs_number: official municipality id
# bfs_name: official municipality name

# Geocoded data (i.e. data with latitude and longitude)
df_geo = pd.read_csv('apartments_data_geocoded.csv', 
                     sep=',', 
                     encoding='utf-8')

# Rename columns
df_geo = df_geo.rename(columns={'web-scrape':'web-scraper-order',
                                'address_ra':'address_raw',
                                'BFS_NUMMER':'bfs_number', 
                                'NAME':'bfs_name'})

# Show data
df_geo[['web-scraper-order',
        'address_raw',
        'lat', 
        'lon', 
        'bfs_number', 
        'bfs_name']].head()
# Out:
#   web-scraper-order                           address_raw        lat  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH  47.252171
# 1      1693998201-2    Zürcherstrasse 1, 8173 Neerach, ZH  47.513332
# 2      1693998201-5     Rotachstrasse 33, 8003 Zürich, ZH  47.370792
# 3     1693998201-16       Wolframplatz 1, 8045 Zürich, ZH  47.362282
# 4     1693998205-25  Badenerstrasse 67, 8953 Dietikon, ZH  47.407925
#
#         lon  bfs_number   bfs_name
# 0  8.845797         118  Rüti (ZH)
# 1  8.474851          88    Neerach
# 2  8.514748         261     Zürich
# 3  8.522193         261     Zürich
# 4  8.392561         243   Dietikon

# %% [markdown]
# ### Join geo-information to rental apartment data using .merge()

# %%
df2 = df.merge(df_geo[['web-scraper-order', 
                       'lat', 
                       'lon', 
                       'bfs_number', 
                       'bfs_name']], 
               on="web-scraper-order")
df2.head()
# Out:
#   web-scraper-order                           address_raw  rooms   area  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0   49.0
# 1      1693998201-2    Zürcherstrasse 1, 8173 Neerach, ZH    3.5   65.0
# 2      1693998201-5     Rotachstrasse 33, 8003 Zürich, ZH    2.0   49.0
# 3     1693998201-16       Wolframplatz 1, 8045 Zürich, ZH    2.0   32.0
# 4     1693998205-25  Badenerstrasse 67, 8953 Dietikon, ZH    3.5  105.0
#
#    luxurious   price  price_per_m2        lat       lon  bfs_number   bfs_name
# 0          0  1441.0         29.41  47.252171  8.845797         118  Rüti (ZH)
# 1          0  1850.0         28.46  47.513332  8.474851          88    Neerach
# 2          0  4335.0         88.47  47.370792  8.514748         261     Zürich
# 3          0  3515.0        109.84  47.362282  8.522193         261     Zürich
# 4          0  3200.0         30.48  47.407925  8.392561         243   Dietikon

# %% [markdown]
# ### Reading municipality-level data

# %%
# Meaning of variables:
# bfs_number: official municipality id
# bfs_name: official municipality name
# pop: number of residents (=population)
# pop_dens: population density (pop per km2)
# frg_pct: percentage foreigners
# emp: numer of employees

df_municip = pd.read_excel('municipality_data.xlsx', 
                           sheet_name='data_for_import')
df_municip.head(5)
# Out:
#    bfs_number            bfs_name    pop     pop_dens    frg_pct     emp  \
# 0           1     Aeugst am Albis   1981   250.442478  14.184755   442.0
# 1           2  Affoltern am Albis  12303  1161.756374  28.700317  6920.0
# 2           3          Bonstetten   5572   749.932705  16.564968  1014.0
# 3           4     Hausen am Albis   3751   275.808824  16.022394  1021.0
# 4           5            Hedingen   3778   578.560490  16.410799  1478.0
#
#   mean_taxable_income
# 0       115285.714286
# 1         74896.28956
# 2        91023.213581
# 3        97382.178804
# 4        94955.074116

# %% [markdown]
# ### Join municipality data to rental apartment data using .merge()

# %%
# Merge needs a key which must be identical in both data sets (here the key is 'bfs_number')
df3 = df2.merge(
    df_municip[[
        'bfs_number',
        'pop',
        'pop_dens',
        'frg_pct',
        'emp',
        'mean_taxable_income'  
    ]],
    on='bfs_number',
    how='left'
)

df3.head(5)
# Out:
#   web-scraper-order                           address_raw  rooms   area  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0   49.0
# 1      1693998201-2    Zürcherstrasse 1, 8173 Neerach, ZH    3.5   65.0
# 2      1693998201-5     Rotachstrasse 33, 8003 Zürich, ZH    2.0   49.0
# 3     1693998201-16       Wolframplatz 1, 8045 Zürich, ZH    2.0   32.0
# 4     1693998205-25  Badenerstrasse 67, 8953 Dietikon, ZH    3.5  105.0
#
#    luxurious   price  price_per_m2        lat       lon  bfs_number  \
# 0          0  1441.0         29.41  47.252171  8.845797         118
# 1          0  1850.0         28.46  47.513332  8.474851          88
# 2          0  4335.0         88.47  47.370792  8.514748         261
# 3          0  3515.0        109.84  47.362282  8.522193         261
# 4          0  3200.0         30.48  47.407925  8.392561         243
#
#     bfs_name     pop     pop_dens    frg_pct       emp mean_taxable_income
# ...

# %% [markdown]
# ### Export data to file

# %%
# Remove missing values which may have ocured from the merging process
df3 = df3.dropna()

# Check for missing values per column
print(df3.isna().sum())

# Count number of rows and columns
print(df3.shape)

# Export apartment data to file
df3.to_csv('apartments_data_enriched.csv',
            sep=',',
            encoding='utf-8')
# Out:
# web-scraper-order      0
# address_raw            0
# rooms                  0
# area                   0
# luxurious              0
# price                  0
# price_per_m2           0
# lat                    0
# lon                    0
# bfs_number             0
# bfs_name               0
# pop                    0
# pop_dens               0
# frg_pct                0
# emp                    0
# mean_taxable_income    0
# dtype: int64
# (816, 16)

# %% [markdown]
# ### Sorting data

# %%
# Sorting data by 'price' and 'area' with highest price above (ascending=False)
df3.sort_values(by=['price', 'area'], 
                ascending=False).head()
# Out:
#     web-scraper-order                             address_raw  rooms   area  \
# 261    1693998265-365    Gustav-Gull-Platz 4, 8004 Zürich, ZH    4.5  140.0
# 262    1693998265-366               Engweg 8, 8006 Zürich, ZH    4.5  140.0
# 145    1693998236-207        Etzelstrasse 35, 8038 Zürich, ZH    3.5  100.0
# 136    1693998236-197             Utoquai 37, 8008 Zürich, ZH    3.5  169.0
# 346    1693998285-475  Universitätstrasse 41, 8006 Zürich, ZH    4.5  140.0
#
#      luxurious   price  price_per_m2        lat       lon  bfs_number  \
# 261          0  9950.0         71.07  47.379471  8.531120         261
# 262          0  9170.0         65.50  47.385265  8.537632         261
# 145          1  9150.0         91.50  47.346546  8.530695         261
# 136          0  9000.0         53.25  47.363682  8.546781         261
# 346          0  8990.0         64.21  47.380440  8.547943         261
#
#     bfs_name     pop     pop_dens    frg_pct       emp mean_taxable_income
# ...

# %% [markdown]
# ### Aggregation of data

# %%
# Aggregation using .groupby()
df3[['rooms', 'price']].groupby(['rooms']).mean()
# Out:
#              price
# rooms
# 1.0    1306.346154
# 1.5    2092.054054
# 2.0    2138.775000
# 2.5    2414.993056
# 3.0    1950.434783
# 3.5    2664.813084
# 4.0    2798.200000
# 4.5    3065.211765
# 5.0    2773.750000
# 5.5    3523.094340
# 6.0    3833.333333
# 6.5    3623.625000
# 7.0    6350.000000
# 7.5    4765.000000
# 8.0    5500.000000
# 8.5    8500.000000

# %% [markdown]
# ## Reshaping data

# %% [markdown]
# ### Reshaping data using .stack() and .unstack()

# %%
df_sub = df3[['bfs_name', 'rooms', 'price', 'area']][:5]
print('Original shape')
print(df_sub, '\n')

df_sub_stacked = df_sub.stack()
print('Stacked')
print(df_sub_stacked, '\n')

# Using unstack
print('Unstacked (= back to original shape)')
print(df_sub_stacked.unstack())
# Out:
# Original shape
#     bfs_name  rooms   price   area
# 0  Rüti (ZH)    3.0  1441.0   49.0
# 1    Neerach    3.5  1850.0   65.0
# 2     Zürich    2.0  4335.0   49.0
# 3     Zürich    2.0  3515.0   32.0
# 4   Dietikon    3.5  3200.0  105.0
#
# Stacked
# 0  bfs_name    Rüti (ZH)
#    rooms             3.0
#    price          1441.0
#    area             49.0
# 1  bfs_name      Neerach
#    rooms             3.5
#    price          1850.0
#    area             65.0
# 2  bfs_name       Zürich
#    rooms             2.0
#    price          4335.0
#    area             49.0
# 3  bfs_name       Zürich
#    rooms             2.0
#    price          3515.0
#    area             32.0
# 4  bfs_name     Dietikon
#    rooms             3.5
#    price          3200.0
#    area            105.0
# dtype: object
#
# Unstacked (= back to original shape)
#     bfs_name rooms   price   area
# 0  Rüti (ZH)   3.0  1441.0   49.0
# 1    Neerach   3.5  1850.0   65.0
# 2     Zürich   2.0  4335.0   49.0
# ...

# %% [markdown]
# ### Reshaping data using .melt()

# %%
df_sub = df3[['rooms', 'price', 'area']][:5]
print('Original shape')
print(df_sub, '\n')

print('Reshaped using .melt()')
print(pd.melt(df, id_vars=['rooms'], value_vars=['price', 'area']))
# Out:
# Original shape
#    rooms   price   area
# 0    3.0  1441.0   49.0
# 1    3.5  1850.0   65.0
# 2    2.0  4335.0   49.0
# 3    2.0  3515.0   32.0
# 4    3.5  3200.0  105.0
#
# Reshaped using .melt()
#       rooms variable   value
# 0       3.0    price  1441.0
# 1       3.5    price  1850.0
# 2       2.0    price  4853.0
# 3       2.0    price  4335.0
# 4       2.0    price  3515.0
# ...     ...      ...     ...
# 1725    3.5     area    82.0
# 1726    4.0     area    73.0
# 1727    4.5     area   110.0
# 1728    3.0     area    68.0
# 1729    4.5     area   114.0
#
# [1730 rows x 3 columns]

# %% [markdown]
# ### Pivoting data using .pivot_table()

# %%
# Using pivot_table to reshape the data and calculate means 
pd.pivot_table(df3[['rooms', 'price', 'area']],
               index=['rooms'],
               values=['price', 'area', 'rooms'],
               aggfunc=(np.mean))
# Out:
#              area        price
# rooms
# 1.0     32.057692  1306.346154
# 1.5     35.972973  2092.054054
# 2.0     54.475000  2138.775000
# 2.5     67.340278  2414.993056
# 3.0     67.956522  1950.434783
# 3.5     89.500000  2664.813084
# 4.0     96.900000  2798.200000
# 4.5    114.670588  3065.211765
# 5.0    103.500000  2773.750000
# 5.5    153.811321  3523.094340
# 6.0    667.666667  3833.333333
# 6.5    248.375000  3623.625000
# 7.0    175.000000  6350.000000
# 7.5    205.000000  4765.000000
# 8.0    160.000000  5500.000000
# 8.5    210.000000  8500.000000

# %% [markdown]
# ### Create Pivot Table for price and price_per_m2

# %%
# === Exercise 3c: Create Pivot Table for price and price_per_m2 (by rooms) ===

pivot_price = df.pivot_table(
    index='rooms',
    values=['price', 'price_per_m2'],
    aggfunc='mean'
)

pivot_price.head()

# === Exercise 3d: Compare price and price_per_m2 ===

# Zeige nochmals die Pivot-Tabelle sortiert nach Zimmerzahl
pivot_price.sort_index()
# Out:
#              price  price_per_m2
# rooms
# 1.0    1309.055556     49.858333
# 1.5    2057.526316     63.732632
# 2.0    2193.476190     43.105476
# 2.5    2460.788079     37.841589
# 3.0    1998.352941     28.892353
# 3.5    2656.564655     29.652328
# 4.0    2763.193548     29.288065
# 4.5    3074.674286     26.473200
# 5.0    2801.000000     25.746000
# 5.5    3591.754386     23.617368
# 6.0    3450.000000     16.572500
# 6.5    3663.411765     19.225882
# 7.0    5400.000000     34.360000
# 7.5    4765.000000     23.273333
# 8.0    5500.000000     34.380000
# 8.5    8500.000000     40.480000

# %% [markdown]
# The average apartment price (price) increases with the number of rooms, as larger apartments are generally more expensive overall.
# However, the average price per square meter (price_per_m2) decreases as the number of rooms increases.
# This indicates that additional living space becomes relatively cheaper, showing an economy of scale effect.

# %% [markdown]
# ### Relationship between area and price_per_m2

# %%
# === Exercise 3e: Relationship between area and price_per_m2 ===

# 1. Korrelation berechnen
corr = df[['area', 'price_per_m2']].corr().iloc[0, 1]
print("Correlation between area and price_per_m2:", round(corr, 3))

# 2. Durchschnittlicher price_per_m2 nach Flächenklassen (Bins)
bins = [0, 40, 60, 80, 100, 150, 200, 10000]
labels = ['<=40', '41-60', '61-80', '81-100', '101-150', '151-200', '>200']
df['area_bin'] = pd.cut(df['area'], bins=bins, labels=labels, right=True)

pivot_area = df.pivot_table(
    index='area_bin',
    values='price_per_m2',
    aggfunc='mean'
)

pivot_area
# Out:
# Correlation between area and price_per_m2: -0.329
#           price_per_m2
# area_bin
# <=40         61.406203
# 41-60        39.254261
# 61-80        32.809323
# 81-100       28.530600
# 101-150      26.845856
# 151-200      25.709756
# >200         16.461250

# %% [markdown]
# There is a negative relationship between the apartment size (area) and the price per square meter (price_per_m2) with a correlation of –0.33.
# This means that larger apartments tend to be cheaper per square meter.
# The pivot table confirms this pattern: small apartments (up to 40 m²) show the highest price per m², while large apartments (above 150 m²) are considerably less expensive per m².

# %% [markdown]
# ### Show the distribution (count) of apartments by number of rooms

# %%
# === Exercise 3f: Show the distribution (count) of apartments by number of rooms ===

# Create a pivot table that counts the number of apartments per room category
pivot_count = df.pivot_table(
    index='rooms',
    values='price',      # any non-empty column works for counting
    aggfunc='count',
    fill_value=0
)

pivot_count.head()
# Out:
#        price
# rooms
# 1.0       54
# 1.5       38
# 2.0       42
# 2.5      151
# 3.0       51

# %% [markdown]
# The pivot table shows how apartments are distributed by the number of rooms.
# Most listings are concentrated in the mid-range categories, such as 2- or 3-room apartments, while very small and very large apartments occur less frequently.

# %% [markdown]
# ### Create Pivot Table with mean values and sort by price and area

# %%
### Exercise 3g – Create Pivot Table with mean values and sort by price and area

pivot_means = df.pivot_table(
    index='area_cat',
    values=['rooms', 'area', 'price', 'price_per_m2'],
    aggfunc='mean'
)

pivot_means_sorted = pivot_means.sort_values(
    by=['price', 'area'],
    ascending=[False, False]
)
pivot_means_sorted.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 3
#       1 ### Exercise 3g – Create Pivot Table with mean values and sort by price and area
# ----> 3 pivot_means = df.pivot_table(
#       4     index='area_cat',
#       5     values=['rooms', 'area', 'price', 'price_per_m2'],
#       6     aggfunc='mean'
#       7 )
#       9 pivot_means_sorted = pivot_means.sort_values(
#      10     by=['price', 'area'],
#      11     ascending=[False, False]
#      12 )
#      13 pivot_means_sorted.head()
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)   9505     sort: bool = True,
#    9506 ) -> DataFrame:
# ...

# %% [markdown]
# The pivot table presents the mean values for rooms, area, price, and price_per_m2 by area category.
# Sorting by price and area shows that larger apartments have higher total prices but lower prices per square meter, confirming the pattern identified in the previous exercises.

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
